# %%
from clinical_codes.tools import ICD10CMClient
from clinical_codes.tools import LOINCClient
from clinical_codes.tools import RxNormClient
from clinical_codes.tools import HCPCSClient
from clinical_codes.tools import UCUMClient
from clinical_codes.tools import HPOClient

from pprint import pprint

# %%
async with ICD10CMClient() as client:
    results = await client.search("hypertension")
    pprint(results)
# Out:
# [CodeResult(system=<SystemName.ICD10CM: 'ICD10CM'>, code='I15.0', display='Renovascular hypertension', score=1.0, raw={'code': 'I15.0', 'display': 'Renovascular hypertension', 'row': ['I15.0', 'Renovascular hypertension']}),
#  CodeResult(system=<SystemName.ICD10CM: 'ICD10CM'>, code='I1A.0', display='Resistant hypertension', score=0.9, raw={'code': 'I1A.0', 'display': 'Resistant hypertension', 'row': ['I1A.0', 'Resistant hypertension']}),
#  CodeResult(system=<SystemName.ICD10CM: 'ICD10CM'>, code='I97.3', display='Postprocedural hypertension', score=0.8, raw={'code': 'I97.3', 'display': 'Postprocedural hypertension', 'row': ['I97.3', 'Postprocedural hypertension']}),
#  CodeResult(system=<SystemName.ICD10CM: 'ICD10CM'>, code='K76.6', display='Portal hypertension', score=0.7, raw={'code': 'K76.6', 'display': 'Portal hypertension', 'row': ['K76.6', 'Portal hypertension']}),
# ...

# %%
async with LOINCClient() as client:
    results = await client.search("glucose")
    pprint(results)
# Out:
# [CodeResult(system=<SystemName.LOINC: 'LOINC'>, code='74790-7', display='Glucose challenge panel', score=1.0, raw={'code': '74790-7', 'display': 'Glucose challenge panel', 'row': ['Glucose challenge panel']}),
#  CodeResult(system=<SystemName.LOINC: 'LOINC'>, code='104708-3', display='Deprecated Est. average glucose Bld-sCnc', score=0.9, raw={'code': '104708-3', 'display': 'Deprecated Est. average glucose Bld-sCnc', 'row': ['Deprecated Est. average glucose Bld-sCnc']}),
#  CodeResult(system=<SystemName.LOINC: 'LOINC'>, code='97510-2', display='% Glucose measurements in range', score=0.8, raw={'code': '97510-2', 'display': '% Glucose measurements in range', 'row': ['% Glucose measurements in range']}),
#  CodeResult(system=<SystemName.LOINC: 'LOINC'>, code='74802-0', display='Glucose HBT ExG-Imp', score=0.7, raw={'code': '74802-0', 'display': 'Glucose HBT ExG-Imp', 'row': ['Glucose HBT ExG-Imp']}),
# ...

# %%
async with RxNormClient() as client:
    results = await client.search("metformin")
    pprint(results)
# Out:
# [CodeResult(system=<SystemName.RXNORM: 'RXNORM'>, code='861007', display='metFORMIN (Oral Pill)', score=1.0, raw={'code': '861007', 'display': 'metFORMIN (Oral Pill)', 'row': ['metFORMIN (Oral Pill)', '861007,861021,2703582,861010,861004', '  500 mg Tab,  625 mg Tab,  750 mg Tab,  850 mg Tab,1,000 mg Tab']}),
#  CodeResult(system=<SystemName.RXNORM: 'RXNORM'>, code='860975', display='metFORMIN XR (Oral Pill)', score=0.9, raw={'code': '860975', 'display': 'metFORMIN XR (Oral Pill)', 'row': ['metFORMIN XR (Oral Pill)', '860975,1807915,1807917,860981,1807888,1807894', '  500 mg 24 HR XR Tab,  500 mg Modified 24 HR XR Tab,  500 mg Osmotic 24 HR XR Tab,  750 mg 24 HR XR Tab,1,000 mg Modified 24 HR XR Tab,1,000 mg Osmotic 24 HR XR Tab']}),
# ...

# %%
async with HCPCSClient() as client:
    results = await client.search("oxygen")
    pprint(results)
# Out:
# [CodeResult(system=<SystemName.HCPCS: 'HCPCS'>, code='C1300', display='Hyperbaric oxygen', score=1.0, raw={'code': 'C1300', 'display': 'Hyperbaric oxygen', 'row': ['C1300', 'Hyperbaric oxygen']}),
#  CodeResult(system=<SystemName.HCPCS: 'HCPCS'>, code='E1390', display='Oxygen concentrator', score=0.9, raw={'code': 'E1390', 'display': 'Oxygen concentrator', 'row': ['E1390', 'Oxygen concentrator']}),
#  CodeResult(system=<SystemName.HCPCS: 'HCPCS'>, code='A4608', display='Transtracheal oxygen cath', score=0.8, raw={'code': 'A4608', 'display': 'Transtracheal oxygen cath', 'row': ['A4608', 'Transtracheal oxygen cath']}),
#  CodeResult(system=<SystemName.HCPCS: 'HCPCS'>, code='E1353', display='Oxygen supplies regulator', score=0.7, raw={'code': 'E1353', 'display': 'Oxygen supplies regulator', 'row': ['E1353', 'Oxygen supplies regulator']}),
# ...

# %%
async with UCUMClient() as client:
    results = await client.search("liter")
    pprint(results)
# Out:
# [CodeResult(system=<SystemName.UCUM: 'UCUM'>, code='10*12/L', display='trillion per liter', score=1.0, raw={'code': '10*12/L', 'display': 'trillion per liter', 'row': ['10*12/L', 'trillion per liter']}),
#  CodeResult(system=<SystemName.UCUM: 'UCUM'>, code='10*6/L', display='million per liter', score=0.9, raw={'code': '10*6/L', 'display': 'million per liter', 'row': ['10*6/L', 'million per liter']}),
#  CodeResult(system=<SystemName.UCUM: 'UCUM'>, code='g/L', display='gram per liter', score=0.8, raw={'code': 'g/L', 'display': 'gram per liter', 'row': ['g/L', 'gram per liter']}),
#  CodeResult(system=<SystemName.UCUM: 'UCUM'>, code='umol/L', display='micromole per liter', score=0.7, raw={'code': 'umol/L', 'display': 'micromole per liter', 'row': ['umol/L', 'micromole per liter']}),
# ...

# %%
async with HPOClient() as client:
    results = await client.search("fever")
    pprint(results)
# Out:
# [CodeResult(system=<SystemName.HPO: 'HPO'>, code='HP:0001945', display='Fever', score=1.0, raw={'code': 'HP:0001945', 'display': 'Fever', 'row': ['HP:0001945', 'Fever']}),
#  CodeResult(system=<SystemName.HPO: 'HPO'>, code='HP:0001954', display='Recurrent fever', score=0.9, raw={'code': 'HP:0001954', 'display': 'Recurrent fever', 'row': ['HP:0001954', 'Recurrent fever']}),
#  CodeResult(system=<SystemName.HPO: 'HPO'>, code='HP:0030245', display='Intrapartum fever', score=0.8, raw={'code': 'HP:0030245', 'display': 'Intrapartum fever', 'row': ['HP:0030245', 'Intrapartum fever']}),
#  CodeResult(system=<SystemName.HPO: 'HPO'>, code='HP:0032323', display='Periodic fever', score=0.7, raw={'code': 'HP:0032323', 'display': 'Periodic fever', 'row': ['HP:0032323', 'Periodic fever']}),
#  CodeResult(system=<SystemName.HPO: 'HPO'>, code='HP:0033087', display='Quotidian fever', score=0.6, raw={'code': 'HP:0033087', 'display': 'Quotidian fever', 'row': ['HP:0033087', 'Quotidian fever']}),
# ...
